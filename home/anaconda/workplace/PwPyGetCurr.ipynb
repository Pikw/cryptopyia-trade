# %%
import requests
import json
import pandas as pd

# %%
path = 'https://www.cryptopia.co.nz/api/GetCurrencies'
r = requests.get(path).encode('utf-8')
r
#r.text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-dbbdccbaf76d> in <module>()
#       1 path = 'https://www.cryptopia.co.nz/api/GetCurrencies'
# ----> 2 r = requests.get(path).encode('utf-8')
#       3 r
#       4 #r.text
#
# AttributeError: 'Response' object has no attribute 'encode'

# %%
jsload = json.loads(r.text)#
jsloadcut = jsload['Data']
#jsload['Data']

# %%
#1
#df = pd.read_json(jsloadcut, typ='records', encoding='utf-8')
#df

# %%
from pandas.io.json import json_normalize
df = json_normalize(jsload['Data'])

# %%
#df
# Out:
#      Algorithm  DepositConfirmations   Id  IsTipEnabled ListingStatus  \
# 0       Scrypt                    20  762         False        Active
# 1         None                    20  573         False        Active
# 2         None                    20  562         False        Active
# 3       Scrypt                   200  427         False        Active
# 4       SHA256                    20  339         False        Active
# 5          POS                   200  108         False        Active
# 6          X11                    20  759         False        Active
# 7       SHA256                    20  285         False        Active
# 8       Scrypt                    20  581         False        Active
# 9         None                    20  593         False        Active
# 10      SHA256                     6  463         False        Active
# 11        None                    20  673         False        Active
# 12      Scrypt                   200  475         False        Active
# 13        None                    20  601         False        Active
# 14        None                     6  493         False        Active
# 15      Scrypt                   200  358         False        Active
# 16      SHA256                   200  350         False        Active
# 17       Other                   200  139         False        Active
# 18        None                    20  654         False        Active
# 19         POS                   200  406         False        Active
# 20         X11                   200  388         False        Active
# 21      Scrypt                    20  301         False        Active
# 22      Scrypt                   200  468         False        Active
# 23      Scrypt                   200   18         False        Active
# 24        None                    20  489         False        Active
# 25      Scrypt                    20  596         False        Active
# 26         POS                    20  125         False        Active
# 27        None                    20  625         False        Active
# 28      Scrypt                    20  508         False        Active
# 29      Scrypt                    20  381         False        Active
# ..         ...                   ...  ...           ...           ...
# 553     Scrypt                   200  373         False        Active
# 554     SHA256                   200  146         False        Active
# 555        POS                   200  181         False     Delisting
# 556      Nist5                    20  590         False        Active
# 557        X13                   200  472         False     Delisting
# 558  NeoScrypt                    20  693         False        Active
# 559       None                    20  723         False        Active
# 560       None                    20  545         False     Delisting
# 561     Scrypt                   200  445         False        Active
# 562     Scrypt                   200  393         False        Active
# 563        X11                   200    8         False        Active
# 564       None                    20  587         False        Active
# 565       None                    20  635         False        Active
# 566     Scrypt                    20  697         False        Active
# 567       None                    20  495         False        Active
# 568     Scrypt                    20  166         False        Active
# 569     SHA256                    20  560         False        Active
# 570     Scrypt                    20  661         False        Active
# 571     Scrypt                    20  522         False        Active
# 572        POS                   200  284         False        Active
# 573       None                    20  708         False        Active
# 574   Equihash                    20  384         False        Active
# 575   Equihash                    10  395         False        Active
# 576    Lyra2RE                    20  380         False        Active
# 577     Scrypt                    20   88         False        Active
# 578   Equihash                    20  629         False        Active
# 579   Equihash                     6  464         False        Active
# 580     SHA256                    20  330         False        Active
# 581    Lyra2RE                    20  396         False        Active
# 582        X11                   200  491         False        Active
#
#       MaxWithdraw  MinBaseTrade    MinTip   MinWithdraw  \
# 0    2.000000e+07       0.00002  0.000000  2.000000e-02
# 1    2.000000e+07       0.00002  1.000000  1.800000e+01
# 2    2.000000e+07       0.00002  0.000000  1.200000e-02
# 3    2.000000e+09       0.00002  0.000000  2.000000e-07
# 4    2.000000e+09       0.00002  5.000000  2.000000e-02
# 5    2.000000e+09       0.00002  0.000000  2.000000e+00
# 6    2.000000e+07       0.00002  0.000000  2.000000e-02
# 7    2.000000e+09       0.00002  0.000000  4.000000e-04
# 8    2.000000e+07       0.00002  0.000000  2.000000e-02
# 9    2.000000e+07       0.00002  0.000000  1.400000e+01
# 10   2.000000e+09       0.00002  0.000000  2.000000e-02
# 11   2.000000e+07       0.00002  0.000000  1.000000e+01
# 12   2.000000e+07       0.00002  1.054852  2.000000e-02
# 13   2.000000e+07       0.00002  0.000000  1.800000e-01
# 14   2.000000e+07       0.00002  0.000000  2.000000e+00
# 15   2.000000e+09       0.00002  0.000000  2.000000e-02
# 16   2.000000e+09       0.00002  0.000000  2.000000e-02
# 17   5.000000e+04       0.00002  0.000000  4.000000e-04
# 18   2.000000e+07       0.00002  0.000000  2.000000e-02
# 19   2.000000e+09       0.00002  0.000000  2.000000e-02
# 20   2.000000e+09       0.00002  0.000000  2.000000e-02
# 21   2.000000e+09       0.00002  7.812500  2.000000e-02
# 22   2.000000e+09       0.00002  0.000000  2.000000e-02
# 23   2.000000e+09       0.00002  0.000000  1.000000e+00
# 24   2.000000e+07       0.00002  0.000000  1.000000e+00
# 25   2.000000e+07       0.00002  0.000000  2.000000e-02
# 26   2.000000e+09       0.00002  0.000000  2.000000e+00
# 27   2.000000e+07       0.00002  0.000000  4.000000e-02
# 28   2.000000e+07       0.00002  0.000000  2.000000e-02
# 29   2.000000e+09       0.00002  0.000000  2.000000e-02
# ..            ...           ...       ...           ...
# 553  2.000000e+09       0.00002  0.000000  2.000000e-02
# 554  2.000000e+09       0.00002  0.000000  4.000000e-04
# 555  2.000000e+09       0.00000  0.000000  4.000000e-04
# 556  2.000000e+07       0.00002  1.976285  2.000000e-02
# 557  2.000000e+07       0.00002  0.000000  2.000000e-02
# 558  2.000000e+07       0.00002  0.000000  2.000000e-02
# 559  2.000000e+07       0.00002  0.000000  4.900000e+02
# 560  2.000000e+07       0.00002  0.000000  2.000000e+00
# 561  2.000000e+09       0.00002  0.000000  2.000000e-02
# 562  2.000000e+09       0.00002  7.692308  2.000000e-02
# 563  2.000000e+09       0.00002  0.000000  2.000000e+01
# 564  2.000000e+07       0.00002  0.000000  1.800000e+01
# 565  2.000000e+07       0.00002  0.000000  2.000000e+01
# 566  2.000000e+07       0.00002  0.000000  2.000000e-02
# 567  2.000000e+07       0.00002  0.000000  2.000000e-02
# 568  2.000000e+09       0.00002  0.000000  4.000000e-04
# 569  2.000000e+07       0.00002  2.127660  2.000000e-02
# 570  2.000000e+07       0.00002  0.000000  2.000000e-02
# 571  2.000000e+07       0.00002  0.750000  1.000000e+02
# 572  2.000000e+09       0.00002  0.420000  4.000000e-04
# 573  2.000000e+07       0.00002  0.000000  3.200000e+01
# 574  1.000000e+04       0.00002  0.000000  1.000000e-03
# 575  2.000000e+09       0.00002  0.000000  2.000000e-02
# 576  2.000000e+09       0.00002  0.000000  2.000000e-02
# 577  2.000000e+09       0.00002  0.000000  2.000000e+01
# 578  2.000000e+07       0.00002  0.000000  2.000000e-02
# 579  2.000000e+09       0.00002  0.000000  2.000000e-02
# 580  2.000000e+09       0.00002  0.000000  2.000000e-02
# 581  2.000000e+09       0.00002  0.000000  2.000000e-02
# 582  2.000000e+07       0.00002  0.000000  2.000000e-02
#
#                        Name         Status  \
# 0                      $PAC             OK
# 1                 21Million             OK
# 2                 300 Token             OK
# 3                   42-coin             OK
# 4                       808             OK
# 5                      8Bit             OK
# 6                       AC3             OK
# 7                     ACoin             OK
# 8                    Adcoin             OK
# 9                  Adshares             OK
# 10              Alexandrite             OK
# 11                     ALIS             OK
# 12                   Allion             OK
# 13                 Alphabit             OK
# 14                  AltCoin             OK
# 15                AmigaCoin             OK
# 16          AnarchistsPrime    Maintenance
# 17                AnimeCoin             OK
# 18                      APX             OK
# 19             AquariusCoin             OK
# 20               ArcticCoin             OK
# 21                 Argentum             OK
# 22                ArgusCoin             OK
# 23                  Aricoin             OK
# 24                      Ark    Maintenance
# 25                  ArtByte             OK
# 26                 Asiacoin             OK
# 27   Athenian Warrior Token             OK
# 28                    Atmos             OK
# 29               Atomiccoin             OK
# ..                      ...            ...
# 553                  Verium             OK
# 554                 Version    Maintenance
# 555               Vibranium    Maintenance
# 556         VirtaUniqueCoin    Maintenance
# 557                   Visio             OK
# 558                    Vivo             OK
# 559                   VOISE             OK
# 560                   VOISE             OK
# 561                 WarCoin  NoConnections
# 562            WayaWolfCoin             OK
# 563            WeAreSatoshi             OK
# 564                    Weed             OK
# 565              WildCrypto             OK
# 566                 Wincoin             OK
# 567            WirelessCoin             OK
# 568               WorldCoin             OK
# 569                   Xcoin             OK
# 570                    XGOX             OK
# 571               XTRABYTES             OK
# 572               YobitCoin             OK
# 573                     Zap             OK
# 574                   ZCash             OK
# 575                Zclassic             OK
# 576                   ZCoin             OK
# 577                ZeitCoin             OK
# 578                 ZenCash             OK
# 579                    Zero  NoConnections
# 580                ZetaCoin             OK
# 581                    Zoin             OK
# 582                 ZSEcoin             OK
#
#                                          StatusMessage Symbol   WithdrawFee
# 0                                                 None   $PAC  1.000000e-02
# 1                                                 None    21M  9.000000e+00
# 2                                                 None    300  6.000000e-03
# 3                                                 None     42  2.000000e-08
# 4                                                 None    808  1.000000e-02
# 5                                                 None   8BIT  1.000000e+00
# 6                                                 None    AC3  1.000000e-02
# 7                                                 None  ACOIN  1.000000e-04
# 8                                                 None    ACC  1.000000e-02
# 9                                                 None   ADST  7.000000e+00
# 10                                                None   ALEX  1.000000e-02
# 11                                                None   ALIS  5.000000e+00
# 12                                                None    ALL  1.000000e-02
# 13                                                None    ABC  9.000000e-02
# 14                                                None    ALT  1.000000e+00
# 15                                                None    AGA  1.000000e-02
# 16                        Investigating network issues    ACP  1.000000e-02
# 17                                                None    ANI  1.000000e-04
# 18                                                None    APX  1.000000e-02
# 19                                                None   ARCO  1.000000e-02
# 20                                                None    ARC  1.000000e-02
# 21                                                None    ARG  1.000000e-02
# 22                                                None  ARGUS  1.000000e-02
# 23                                                None    ARI  5.000000e-01
# 24                      March 4th. Rescanning Deposits    ARK  1.000000e-01
# 25                                                None    ABY  1.000000e-02
# 26                                                None     AC  1.000000e+00
# 27                                                None    ATH  2.000000e-02
# 28                                                None   ATMS  1.000000e-02
# 29                                                None   ATOM  1.000000e-02
# ..                                                 ...    ...           ...
# 553                                               None    VRM  1.000000e-02
# 554           18-02-18 Investigating Withdrawal issues      V  1.000000e-04
# 555                                               None    XVI  1.000000e-04
# 556                  11/01/18 As requested by Coin Dev    VUC  1.000000e-02
# 557  Due to ongoing wallet issues VISIO has been sc...  VISIO  1.000000e-02
# 558                                               None   VIVO  1.000000e-02
# 559                                               None  VOISE  2.450000e+02
# 560                                                       VSM  1.000000e+00
# 561                                               None    WRC  1.000000e-02
# 562                                               None     WW  1.000000e-02
# 563                                               None    WSX  1.000000e+01
# 564                                               None   WEED  9.000000e+00
# 565                                               None   WILD  1.000000e+01
# 566                                               None     WC  1.000000e-02
# 567                                               None    WLC  1.000000e-02
# 568                                               None    WDC  1.000000e-04
# 569                                               None    XCO  1.000000e-02
# 570                                               None   XGOX  1.000000e-02
# 571                                               None    XBY  1.000000e+00
# 572                                               None   YOVI  1.000000e-04
# 573                                               None    ZAP  1.600000e+01
# 574                                               None    ZEC  2.000000e-04
# 575                                               None    ZCL  1.000000e-02
# 576                                               None    XZC  1.000000e-02
# 577                                               None   ZEIT  1.000000e+01
# 578                                               None    ZEN  1.000000e-02
# 579                                               None    ZER  1.000000e-02
# 580                                               None    ZET  1.000000e-02
# 581                                               None    ZOI  1.000000e-02
# 582                                               None    ZSE  1.000000e-02
#
# [583 rows x 14 columns]

# %%
#df
#df['Id']
#df.head()
#df.sort_values(by='Id')..T
#df[df['Name'] == 'ACoin']
#df[df['Id'] < 10].sort_values(by='Id')
df[df['Status'] != 'OK'].sort_values(by='Id')
# Out:
#        Algorithm  DepositConfirmations   Id  IsTipEnabled ListingStatus  \
# 525       SHA256                    20   53         False        Active
# 221       Scrypt                    20   65         False        Active
# 351       Scrypt                   200   70         False        Active
# 226       Scrypt                   200  112         False        Active
# 464       Scrypt                    20  132         False        Active
# 554       SHA256                   200  146         False        Active
# 555          POS                   200  181         False     Delisting
# 552       Scrypt                    20  184         False        Active
# 36        Scrypt                   400  215         False        Active
# 537          POS                   200  226         False     Delisting
# 42        Scrypt                   200  258         False     Delisting
# 193       Scrypt                   200  259         False        Active
# 158     Blake256                    20  264         False        Active
# 322       Scrypt                    20  271         False        Active
# 357          POS                    20  278         False        Active
# 101       Scrypt                   200  305         False     Delisting
# 16        SHA256                   200  350         False        Active
# 280       Scrypt                   200  360         False        Active
# 495       Scrypt                   200  372         False        Active
# 478          X11                    20  405         False        Active
# 409        Other                    20  410         False     Delisting
# 444        Other                   200  429         False        Active
# 41           X11                   200  439         False        Active
# 35        Scrypt                  1000  444         False     Delisting
# 561       Scrypt                   200  445         False        Active
# 508          POS                   200  449         False        Active
# 223       SHA256                   200  456         False        Active
# 516       Scrypt                   200  457         False        Active
# 579     Equihash                     6  464         False        Active
# 410        Other                    20  478         False        Active
# 366       Ethash                    20  482         False        Active
# 24          None                    20  489         False        Active
# 46        Scrypt                   200  499         False        Active
# 89        Scrypt                    20  501         False        Active
# 66        Scrypt                    20  507         False        Active
# 219         None                   200  513         False        Active
# 165       Scrypt                     6  523         False     Delisting
# 292         None                    20  549         False        Active
# 461  CryptoNight                    20  556         False        Active
# 556        Nist5                    20  590         False        Active
# 295        Qubit                    20  611         False        Active
# 379         None                    20  633         False        Active
# 266          X11                    20  667         False        Active
# 191  CryptoNight                    20  695         False        Active
# 488        Quark                    20  735         False        Active
#
#       MaxWithdraw  MinBaseTrade    MinTip  MinWithdraw                Name  \
# 525  2.000000e+04       0.00002  0.000000      2.00000             TitCoin
# 221  2.000000e+09       0.00002  0.000000     20.00000  FeatherCoinClassic
# 351  2.000000e+06       0.00002  0.000000      2.00000      MetalMusicCoin
# 226  1.000000e+07       0.00002  0.000000    200.00000         FloripaCoin
# 464  2.000000e+09       0.00002  0.000000      2.00000          RussiaCoin
# 554  2.000000e+09       0.00002  0.000000      0.00040             Version
# 555  2.000000e+09       0.00000  0.000000      0.00040           Vibranium
# 552  2.000000e+09       0.00002  0.000000      0.00040            VeriCoin
# 36   2.000000e+09       0.00002  0.000000      0.00040                BATA
# 537  2.000000e+09       0.00002  0.000000      0.00040          TurboStake
# 42   2.000000e+09       0.00002  0.000000      0.00040          BeaverCoin
# 193  2.000000e+09       0.00002  0.000000      0.00040        ElephantCoin
# 158  2.000000e+09       0.00002  0.000000      0.04000              Decred
# 322  2.000000e+09       0.00002  0.045286      0.00040             LiteBar
# 357  2.000000e+09       0.00002  0.000000      0.00040                MOIN
# 101  2.000000e+09       0.00002  0.000000      0.02000          CasinoCoin
# 16   2.000000e+09       0.00002  0.000000      0.02000     AnarchistsPrime
# 280  2.000000e+09       0.00002  0.000000      0.02000        InfiniteCoin
# 495  2.000000e+09       0.00002  0.000000      0.02000           SpaceCoin
# 478  2.000000e+09       0.00002  0.000000      0.02000  SiberianChervonets
# 409  2.000000e+09       0.00002  0.000000      0.02000          PascalCoin
# 444  2.000000e+09       0.00002  2.793296      0.02000            PureVidz
# 41   2.000000e+09       0.00002  0.010000      0.02000            BeatCoin
# 35   2.000000e+09       0.00002  0.000000      0.02000             B3 Coin
# 561  2.000000e+09       0.00002  0.000000      0.02000             WarCoin
# 508  2.000000e+09       0.00002  0.000000      0.02000       StopTrumpCoin
# 223  2.000000e+09       0.00002  0.000000      0.02000     FireRoosterCoin
# 516  2.000000e+09       0.00002  0.000000      0.02000          TattooCoin
# 579  2.000000e+09       0.00002  0.000000      0.02000                Zero
# 410  2.000000e+07       0.00002  0.000000      0.02000          PascalLite
# 366  2.000000e+07       0.00002  1.000000      0.02000            Musicoin
# 24   2.000000e+07       0.00002  0.000000      1.00000                 Ark
# 46   2.000000e+07       0.00002  0.000000      0.02000           BestChain
# 89   2.000000e+07       0.00002  0.000000      0.00004      Byteball Bytes
# 66   2.000000e+07       0.00002  0.000000      0.02000             Bitstar
# 219  2.000000e+07       0.00002  0.325000      0.02000            FazzCoin
# 165  2.000000e+07       0.00002  0.000000   2000.00000            DIBCOIN
# 292  2.000000e+07       0.00002  0.000000      6.00000             JetCoin
# 461  2.000000e+07       0.00002  1.000000      0.02000           Royalties
# 556  2.000000e+07       0.00002  1.976285      0.02000     VirtaUniqueCoin
# 295  2.000000e+07       0.00002  0.000000      0.02000        KangarooBits
# 379  2.000000e+07       0.00002  0.000000     24.00000            NeuroDAO
# 266  2.000000e+07       0.00002  0.000000      0.02000              Helium
# 191  5.000000e+04       0.00002  0.000000     20.00000         Electroneum
# 488  2.000000e+07       0.00002  0.000000      0.02000          SocialSend
#
#             Status                                      StatusMessage Symbol  \
# 525    Maintenance    1st February - Withdraw issues - dusting wallet    TIT
# 221    Maintenance  Low connections, No New blocks seen since  201...   FTCC
# 351    Maintenance                   Investigating transaction issues  MTLMC
# 226    Maintenance                        Investigating wallet issues    FLN
# 464  NoConnections                                               None     RC
# 554    Maintenance           18-02-18 Investigating Withdrawal issues      V
# 555    Maintenance                                               None    XVI
# 552    Maintenance                   21/02/18 - Resolving recent fork    VRC
# 36   NoConnections                                               None    BTA
# 537    Maintenance  13th December - Block explorer provided by TRB...   TRBO
# 42     Maintenance                                            Forked!    BVC
# 193    Maintenance  12/Jan/18 Investigating wallet issues. next st...    ELP
# 158    Maintenance         18-02-18 - investigating withdrawal issues    DCR
# 322    Maintenance             05-03-18 Awaiting update From Coin DEV    LTB
# 357    Maintenance                       5th March: Rebuilding wallet   MOIN
# 101    Maintenance  CSC has been victim of a 51% attack. We are cu...    CSC
# 16     Maintenance                       Investigating network issues    ACP
# 280    Maintenance  22nd January - IFC network was the victim of a...    IFC
# 495  NoConnections                                               None  SPACE
# 478    Maintenance             24th January - Wallet server migration    SIB
# 409  NoConnections  Due to ongoing wallet issues PASC has been sch...   PASC
# 444  NoConnections                                               None   VIDZ
# 41     Maintenance                                 2/3/18 - Resyncing   XBTS
# 35   NoConnections                                               None     B3
# 561  NoConnections                                               None    WRC
# 508  NoConnections                                               None    STC
# 223  NoConnections                                               None    FRC
# 516  NoConnections                          14/12/17 - No connections    TSE
# 579  NoConnections                                               None    ZER
# 410    Maintenance               27-02-18 Checking Transaction Issues   PASL
# 366    Maintenance                                        Maintenance  MUSIC
# 24     Maintenance                     March 4th. Rescanning Deposits    ARK
# 46   NoConnections                                               None   BEST
# 89     Maintenance                         24/02/2018 - Wallet update  GBYTE
# 66     Maintenance  15/02/18 - In maintenance while working out th...   BITS
# 219    Maintenance  27th Feb. Investigating deposit/withdrawal issues   FAZZ
# 165    Maintenance  14/12/17 - Wallet Mandatory Update\r\n\r\n25th...   DIBC
# 292        Offline  Due to a mistake, we ran out of the old JET to...    JET
# 461  NoConnections                                               None    XRY
# 556    Maintenance                  11/01/18 As requested by Coin Dev    VUC
# 295    Maintenance     06/09/2017 Wallet issues with Missing Coin Dev    KGB
# 379    Maintenance  The NDAO smart contract ran into some issues. ...   NDAO
# 266        Offline                                               None    HLM
# 191    Maintenance  04/03/2018 - ETN in maintenance, investigating...    ETN
# 488    Maintenance                             9/3/18 Updating wallet   SEND
#
#      WithdrawFee
# 525      1.00000
# 221     10.00000
# 351      1.00000
# 226    100.00000
# 464      1.00000
# 554      0.00010
# 555      0.00010
# 552      0.00010
# 36       0.00010
# 537      0.00010
# 42       0.00010
# 193      0.00010
# 158      0.03000
# 322      0.00010
# 357      0.00010
# 101      0.01000
# 16       0.01000
# 280      0.01000
# 495      0.01000
# 478      0.01000
# 409      0.01000
# 444      0.01000
# 41       0.01000
# 35       0.01000
# 561      0.01000
# 508      0.01000
# 223      0.01000
# 516      0.01000
# 579      0.01000
# 410      0.01000
# 366      0.01000
# 24       0.10000
# 46       0.01000
# 89       0.00002
# 66       0.01000
# 219      0.01000
# 165   1200.00000
# 292      3.00000
# 461      0.01000
# 556      0.01000
# 295      0.01000
# 379     12.00000
# 266      0.01000
# 191     10.00000
# 488      0.01000
